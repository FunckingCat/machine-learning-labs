# %% [markdown]
# ## Краткое описание
#
# Разработка программы, которая осуществляет поиск кратчайшего пути для информационного пакета (сообщения) в компьютерной сети с помощью генетических алгоритмов.
#
# ### 1. Цель работы
#
# Ознакомиться с подходом и приобрести практический навык решения оптимизационных задач с помощью генетических алгоритмов (ГА).
#
# ### 2. Порядок выполнения работы
#
# 1. Изучить теоретическое введение.
# 2. Самостоятельно разработать компьютерную программу (среда разработки выбирается студентом самостоятельно).
# 3. Провести серию из 5+ испытаний для изучения принципов работы ГА.
# 4. Оформить отчет по лабораторной работе.
#
# ### 3. Требования к функциональности компьютерной программы
#
# - Возможность задания топологии сети с указанием её размерности и пропускной способностью каналов.
# - Настройки работы генетического алгоритма: размер популяции, количество поколений, варианты кроссовера, вероятность мутации и др.
# - Указание исходных данных (компьютер-отправитель и компьютер-получатель) и автоматическое заполнение исходных данных топологии сети.
# - Два режима работы:
#   - **Пошаговый**: на экране должны отображаться все представители (хромосомы) одного поколения до и после применения каждого оператора (скрещивания, селекции, редукции и мутации).
#   - **Циклический**: на экране должны отражаться только агрегированные данные по каждому поколению и итоговый набор хромосом.
# - На одной из экранных форм должны быть указаны ФИО и e-mail автора приложения, ссылка на учебный курс и год разработки. Эти данные должны быть продублированы в тексте программы (каждого программного модуля).
# - Дополнительно необходимо реализовать возможность динамического изменения исходных данных (матрицы связанности графа) во время пошагового режима работы алгоритма.
#
# ### 4. Рекомендации по реализации
#
# - В качестве хромосомы рекомендуется выбрать постоянную по длине последовательность вершин или дуг. Длину можно выбрать произвольную, но не меньше, чем `N–2`, где `N` — общее количество компьютеров в сети.
# - Для упрощения расчётов граф сети лучше сделать полносвязанным (каждая пара вершин имеет связь). Для обозначения отсутствия связи нужно выбрать очень большое значение веса дуги, а для петли — значение веса равное 0.
# - Если в качестве хромосомы используется последовательность вершин, необходимо либо исключить первую и последнюю вершину (т.е. задавать только вершины пути), либо не изменять их в результате применения генетических операторов.
# - Допускается использование в качестве генов букв или чисел в десятеричной системе. Если используется битовая строка, лучше выбрать количество серверов, равное `2^n` (16, 32, 64 и т.д.).
# - Если в исходной популяции не представлены все возможные вершины (гены), они могут появиться только в результате мутации, поэтому рекомендуется в начальной выборке представить весь генофонд.
# - Если выбранный алгоритм скрещивания изменяет только правую (левую) часть хромосомы или только 4 гена из 10, его эффективность может быть низкой, и остаётся надежда только на мутацию и удачные исходные данные.
# - Повторяющиеся (идентичные) хромосомы лучше исключать (удалять, мутировать) на начальных этапах. Если размер популяции фиксированный, это может быть неизбежным при сходимости алгоритма и вырождении популяции.
#
# ### 5. Содержание отчета
#
# 1. Название и цель работы.
# 2. Задание, краткое описание предметной области и выбранной задачи.
# 3. Блок-схема с пояснениями реализованного ГА и каждого оператора в отдельности.
# 4. Протоколы проведенных экспериментов (5+), представленные в форме графиков (допускаются скриншоты при программной реализации этой функциональности).
# 5. Выводы и рекомендации по использованию разработанных ГА.

# %% [markdown]
# # Выполнение задания
#
# Выполнил: Журавлев Д. А. Группа 211-321
#
# Учебный курс: Методы работы с большими данными
#
# ## Основы генетических алгоритмов (ГА)
#
# Генетический алгоритм — это метод оптимизации, основанный на принципах естественного отбора и генетики. Алгоритм имитирует процесс эволюции, чтобы найти решение задачи, начиная с набора случайных решений и улучшая их через последовательные итерации.
#
# ## Основные этапы генетического алгоритма:
#
# 1. **Инициализация популяции:**
#    - Создается начальная популяция возможных решений (хромосом).
#    - Хромосомы могут быть представлены в виде строк (например, последовательности чисел или битов).
#
# 2. **Оценка пригодности (fitness function):**
#    - Каждой хромосоме присваивается значение пригодности, которое оценивает её качество в контексте задачи.
#
# 3. **Селекция (отбор):**
#    - Выбираются лучшие хромосомы для создания следующего поколения. Популярные методы: турнирный отбор, рулетка.
#
# 4. **Кроссовер (скрещивание):**
#    - Избранные хромосомы объединяются, образуя потомков. Это позволяет комбинировать черты родительских решений.
#
# 5. **Мутация:**
#    - В потомках случайным образом изменяются отдельные гены с определённой вероятностью. Это предотвращает преждевременную сходимость и поддерживает генетическое разнообразие.
#
# 6. **Редукция и замена популяции:**
#    - Формируется новая популяция из потомков, возможно с сохранением лучших представителей предыдущего поколения (элитизм).
#
# 7. **Завершение алгоритма:**
#    - Алгоритм завершается, когда достигнуто максимальное количество поколений или решение стабилизировалось (не изменяется от поколения к поколению).
#
# ## Поиск кратчайшего пути в сети
#
# Задача поиска кратчайшего пути заключается в нахождении оптимального маршрута между двумя узлами (вершинами) в графе, минимизируя суммарный вес дуг (рёбер), представляющих пропускную способность или расстояние.
#
# ### Особенности задачи:
#
# - Граф — это полносвязная сеть, где отсутствующие связи заменяются большим значением веса.
# - Хромосома будет представлять собой последовательность узлов (вершин) от источника к приёмнику.
# - Оценка пригодности (fitness function) будет определяться длиной пути — чем короче путь, тем выше значение пригодности.

# %%
import numpy as np

#Key parameters

NUM_NODES = 10
MAX_WEIGHT = 1000

POPULATION_SIZE = 10
START_NODE = 0
END_NODE = 9

NUM_GENERATIONS = 50
TOURNAMENT_SIZE = 3
MUTATION_RATE = 0.3

STEP_BY_STEP = True
GENERATION_LOG_STEP = 1 if STEP_BY_STEP else 5

TRACE_ENABLED = True
DEBUG_ENABLED = True if STEP_BY_STEP else False
INFO_ENABLED = True

ALTER_TOPOLOGY = True
ALTER_TOPOLOGY_MAP = {
    10: np.array([[  0, 436, 861, 271, 107,  72, 701,  21, 615, 122],
                  [467,   0, 331, 459,  88, 373, 100, 872, 664, 131],
                  [662, 309,   0, 344, 492, 414, 806, 386, 192, 956],
                  [277, 161, 460,   0,  22, 253, 748, 857, 561, 475],
                  [ 59, 511, 682, 476,   0, 976, 783, 190, 958, 687],
                  [958, 563, 876, 567, 244,   0, 505, 131, 485, 819],
                  [647,  21, 841, 167, 274, 388,   0, 316,  14, 242],
                  [777, 346, 565, 898, 340,  92, 367,   0, 455, 428],
                  [509, 776, 943,  35, 206,  81, 932, 562,   0, 388],
                  [  2, 390, 566, 106, 772, 822, 477, 703, 402,   0]]),
}

np.random.seed(42)

# %%
### Helper functions
from enum import Enum

class Level(Enum):
    TRACE = 0
    DEBUG = 1
    INFO = 2

def log(level: Level, obj):
    if (level == Level.TRACE and TRACE_ENABLED):
        print(obj)
    if (level == Level.DEBUG and DEBUG_ENABLED):
        print(obj)
    if (level == Level.INFO and INFO_ENABLED):
        print(obj)

# %%
def init_topology(num_nodes: int, max_weight: int):
    adjacency_matrix = np.random.randint(1, max_weight, size=(num_nodes, num_nodes))
    np.fill_diagonal(adjacency_matrix, 0)
    return adjacency_matrix

topology = init_topology(NUM_NODES, MAX_WEIGHT)

def alter_topology(generation): 
    global topology
    if (ALTER_TOPOLOGY and generation in ALTER_TOPOLOGY_MAP):
        log(Level.DEBUG, "\n---\n")
        log(Level.DEBUG, f"Alter topology: \n{topology}\n before ---> after \n{ALTER_TOPOLOGY_MAP[generation]}\n")
        if (ALTER_TOPOLOGY_MAP[generation].shape != (NUM_NODES, NUM_NODES)):
            raise Exception(f"Invalid Alter Topology {ALTER_TOPOLOGY_MAP[generation].shape}")
        topology = ALTER_TOPOLOGY_MAP[generation]

topology
# Out:
# array([[  0, 436, 861, 271, 107,  72, 701,  21, 615, 122],
#        [467,   0, 331, 459,  88, 373, 100, 872, 664, 131],
#        [662, 309,   0, 344, 492, 414, 806, 386, 192, 956],
#        [277, 161, 460,   0,  22, 253, 748, 857, 561, 475],
#        [ 59, 511, 682, 476,   0, 976, 783, 190, 958, 687],
#        [958, 563, 876, 567, 244,   0, 505, 131, 485, 819],
#        [647,  21, 841, 167, 274, 388,   0, 316,  14, 242],
#        [777, 346, 565, 898, 340,  92, 367,   0, 455, 428],
#        [509, 776, 943,  35, 206,  81, 932, 562,   0, 388],
#        [  2, 390, 566, 106, 772, 822, 477, 703, 402,   0]])

# %%
def initialize_population(population_size: int, num_nodes: int, start_node: int, end_node: int):
    population = []
    for _ in range(population_size):
        route = list(np.random.permutation(num_nodes))
        route.remove(start_node)
        route.remove(end_node)
        route = [start_node] + route + [end_node]
        population.append(route)
    return population

initial_population = initialize_population(POPULATION_SIZE, NUM_NODES, START_NODE, END_NODE)
log(Level.INFO, '\n'.join(map(str, initial_population)))
# Out:
# [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]
# [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]
# [0, 1, 5, 2, 4, 3, 7, 6, 8, 9]
# [0, 3, 1, 4, 5, 8, 6, 7, 2, 9]
# [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]
# [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]
# [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]
# [0, 8, 4, 1, 5, 7, 2, 6, 3, 9]

# %%
def calculate_route_len(route, adjacency_matrix, showTrace=False):
    total_distance = 0
    route_trace = f"Trace route {str(route)}: 0 "
    for i in range(len(route) - 1):
        total_distance += adjacency_matrix[route[i]][route[i + 1]]
        route_trace = route_trace + f"-> {adjacency_matrix[route[i]][route[i + 1]]} "

    if (showTrace):
        log(Level.TRACE, route_trace)

    return total_distance

def calculate_fitness(route, adjacency_matrix):
    return int(10000000 / calculate_route_len(route, adjacency_matrix))

def route_to_str(route):
    return f"{route}/Len-{calculate_route_len(route, topology)}/Fit-{calculate_fitness(route, topology)}"

log(Level.INFO, '\n'.join(map(route_to_str, initial_population)))
# Out:
# [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
# [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
# [0, 1, 5, 2, 4, 3, 7, 6, 8, 9]/Len-4279/Fit-2336
# [0, 3, 1, 4, 5, 8, 6, 7, 2, 9]/Len-4750/Fit-2105
# [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
# [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
# [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]/Len-4278/Fit-2337
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
# [0, 8, 4, 1, 5, 7, 2, 6, 3, 9]/Len-3849/Fit-2598

# %%
def selection(population: list, fitness_scores):
    selected_indices = np.random.choice(len(population), TOURNAMENT_SIZE, replace=False)
    best_index = selected_indices[np.argmax([fitness_scores[i] for i in selected_indices])]

    intdent = "\n                 "
    log(Level.DEBUG, f"selection:\n\t\
        indexes: {selected_indices}\n\t\
        tournament:{intdent}{intdent.join(map(route_to_str, [population[i] for i in selected_indices]))}\n\t\
        winner: {route_to_str(population[best_index])}")

    return population[best_index]

# %%
def crossover(parent1, parent2):
    size = len(parent1)
    crossover_point = np.random.randint(1, size - 1)
    child1 = parent1[:crossover_point] + [node for node in parent2 if node not in parent1[:crossover_point]]
    child2 = parent2[:crossover_point] + [node for node in parent1 if node not in parent2[:crossover_point]]
    
    log(Level.DEBUG, f"crossover:\n\t\
        point {crossover_point}:\n\t\
        Child1 = {parent1} + {parent2} -> {child1}\n\t\
        Child2 = {parent1} + {parent2} -> {child2}")

    return child1, child2

# %%
def mutate(route):
    old_route = route[:]
    if np.random.rand() < MUTATION_RATE:
        idx1, idx2 = np.random.choice(range(1, len(route) - 1), size=2, replace=False)
        route[idx1], route[idx2] = route[idx2], route[idx1]
        log(Level.DEBUG, f"mutation: {old_route} -> {route}")
    return route

# %%
def genetic_algorithm(adjacency_matrix):    

    population = initial_population
    
    for generation in range(NUM_GENERATIONS + 1):

        alter_topology(generation)

        fitness_scores = [calculate_fitness(route, adjacency_matrix) for route in population]
        
        log_generation(generation, population, fitness_scores)

        new_population = []
        while len(new_population) < POPULATION_SIZE:
            parent1 = selection(population, fitness_scores)
            parent2 = selection(population, fitness_scores)
            children = crossover(parent1, parent2)
            for child in children:
                child = mutate(child)
                if child not in new_population:
                    new_population.append(child)
                else:
                    log(Level.DEBUG, f"Child already present in population {child}")
        
        population = new_population[:POPULATION_SIZE]

    final_fitness_scores = [calculate_fitness(route, adjacency_matrix) for route in population]
    best_fitness = max(final_fitness_scores)
    best_route = population[np.argmax(final_fitness_scores)]

    print(f"\nBest fitness: {best_fitness}")
    print(f"Route len: {calculate_route_len(best_route, topology, True)}")
    
    return best_route, best_fitness

def log_generation(generation, population, fitness_scores):
    if generation % GENERATION_LOG_STEP != 0:
        return
    best_fitness = max(fitness_scores)
    best_route = population[np.argmax(fitness_scores)]
    full_population_string = '\n'.join(map(route_to_str, population))
    log(Level.DEBUG, "\n---\n")
    log(Level.INFO, f"Generation {generation}: Best Fitness = {best_fitness}, Best Route = {best_route}, Best Route len = {str(calculate_route_len(best_route, topology))}")
    log(Level.DEBUG, f"Full population:\n{full_population_string}\n")

# Запуск алгоритма
best_route, best_fitness = genetic_algorithm(topology)
# Out:
# ---
#
# Generation 0: Best Fitness = 3353, Best Route = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9], Best Route len = 2982
# Full population:
# [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
# [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
# [0, 1, 5, 2, 4, 3, 7, 6, 8, 9]/Len-4279/Fit-2336
# [0, 3, 1, 4, 5, 8, 6, 7, 2, 9]/Len-4750/Fit-2105
# [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
# [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
# [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]/Len-4278/Fit-2337
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
# [0, 8, 4, 1, 5, 7, 2, 6, 3, 9]/Len-3849/Fit-2598
#
# selection:
# 	        indexes: [0 2 1]
# 	        tournament:
#                  [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
#                  [0, 1, 5, 2, 4, 3, 7, 6, 8, 9]/Len-4279/Fit-2336
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
# 	        winner: [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
# selection:
# 	        indexes: [1 2 7]
# 	        tournament:
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
#                  [0, 1, 5, 2, 4, 3, 7, 6, 8, 9]/Len-4279/Fit-2336
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# crossover:
# 	        point 6:
# 	        Child1 = [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 2, 8, 7, 6, 3, 5, 1, 9]
# 	        Child2 = [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# mutation: [0, 4, 2, 8, 7, 6, 3, 5, 1, 9] -> [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]
# selection:
# 	        indexes: [8 1 4]
# 	        tournament:
#                  [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
# 	        winner: [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
# selection:
# 	        indexes: [6 4 7]
# 	        tournament:
#                  [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]/Len-4278/Fit-2337
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# crossover:
# 	        point 8:
# 	        Child1 = [0, 1, 8, 5, 2, 7, 4, 3, 6, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]
# 	        Child2 = [0, 1, 8, 5, 2, 7, 4, 3, 6, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# mutation: [0, 1, 8, 5, 2, 7, 4, 3, 6, 9] -> [0, 1, 8, 5, 2, 6, 4, 3, 7, 9]
# selection:
# 	        indexes: [9 8 7]
# 	        tournament:
#                  [0, 8, 4, 1, 5, 7, 2, 6, 3, 9]/Len-3849/Fit-2598
#                  [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# selection:
# 	        indexes: [4 8 1]
# 	        tournament:
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
#                  [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
# 	        winner: [0, 1, 8, 5, 2, 7, 4, 3, 6, 9]/Len-4249/Fit-2353
# crossover:
# 	        point 5:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 1, 8, 5, 2, 7, 4, 3, 6, 9] -> [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 1, 8, 5, 2, 7, 4, 3, 6, 9] -> [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]
# selection:
# 	        indexes: [9 1 7]
# 	        tournament:
#                  [0, 8, 4, 1, 5, 7, 2, 6, 3, 9]/Len-3849/Fit-2598
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# selection:
# 	        indexes: [7 1 4]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# selection:
# 	        indexes: [0 4 3]
# 	        tournament:
#                  [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
#                  [0, 3, 1, 4, 5, 8, 6, 7, 2, 9]/Len-4750/Fit-2105
# 	        winner: [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
# selection:
# 	        indexes: [6 2 4]
# 	        tournament:
#                  [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]/Len-4278/Fit-2337
#                  [0, 1, 5, 2, 4, 3, 7, 6, 8, 9]/Len-4279/Fit-2336
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
# 	        winner: [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]/Len-4278/Fit-2337
# crossover:
# 	        point 5:
# 	        Child1 = [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] + [0, 6, 1, 3, 8, 7, 5, 4, 2, 9] -> [0, 4, 2, 8, 7, 6, 1, 3, 5, 9]
# 	        Child2 = [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] + [0, 6, 1, 3, 8, 7, 5, 4, 2, 9] -> [0, 6, 1, 3, 8, 4, 2, 7, 5, 9]
# selection:
# 	        indexes: [0 5 1]
# 	        tournament:
#                  [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
#                  [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
#                  [0, 5, 2, 7, 3, 8, 6, 1, 4, 9]/Len-4521/Fit-2211
# 	        winner: [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]/Len-3157/Fit-3167
# selection:
# 	        indexes: [6 5 4]
# 	        tournament:
#                  [0, 6, 1, 3, 8, 7, 5, 4, 2, 9]/Len-4278/Fit-2337
#                  [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
#                  [0, 2, 4, 5, 1, 7, 3, 8, 6, 9]/Len-6397/Fit-1563
# 	        winner: [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] + [0, 7, 1, 8, 3, 2, 4, 5, 6, 9] -> [0, 4, 2, 8, 7, 6, 5, 3, 1, 9]
# 	        Child2 = [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] + [0, 7, 1, 8, 3, 2, 4, 5, 6, 9] -> [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]
# mutation: [0, 4, 2, 8, 7, 6, 5, 3, 1, 9] -> [0, 4, 2, 8, 7, 6, 5, 1, 3, 9]
#
# ---
#
# Generation 1: Best Fitness = 3526, Best Route = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9], Best Route len = 2836
# Full population:
# [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# [0, 1, 8, 5, 2, 6, 4, 3, 7, 9]/Len-4898/Fit-2041
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
# [0, 4, 2, 8, 7, 6, 1, 3, 5, 9]/Len-3462/Fit-2888
# [0, 6, 1, 3, 8, 4, 2, 7, 5, 9]/Len-3927/Fit-2546
# [0, 4, 2, 8, 7, 6, 5, 1, 3, 9]/Len-3795/Fit-2635
# [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
#
# selection:
# 	        indexes: [9 5 4]
# 	        tournament:
#                  [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# selection:
# 	        indexes: [5 1 4]
# 	        tournament:
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# crossover:
# 	        point 4:
# 	        Child1 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]
# selection:
# 	        indexes: [3 0 1]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# 	        winner: [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# selection:
# 	        indexes: [8 1 5]
# 	        tournament:
#                  [0, 4, 2, 8, 7, 6, 5, 1, 3, 9]/Len-3795/Fit-2635
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# crossover:
# 	        point 1:
# 	        Child1 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# 	        Child2 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]
# mutation: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]
# selection:
# 	        indexes: [5 1 3]
# 	        tournament:
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# selection:
# 	        indexes: [5 1 2]
# 	        tournament:
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 1, 8, 5, 2, 6, 4, 3, 7, 9]/Len-4898/Fit-2041
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# crossover:
# 	        point 2:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# selection:
# 	        indexes: [0 4 3]
# 	        tournament:
#                  [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# selection:
# 	        indexes: [3 5 4]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# crossover:
# 	        point 2:
# 	        Child1 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# 	        Child2 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]
# Child already present in population [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]
# selection:
# 	        indexes: [2 5 9]
# 	        tournament:
#                  [0, 1, 8, 5, 2, 6, 4, 3, 7, 9]/Len-4898/Fit-2041
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
#                  [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
# 	        winner: [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
# selection:
# 	        indexes: [1 9 4]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# crossover:
# 	        point 4:
# 	        Child1 = [0, 7, 1, 8, 3, 2, 4, 5, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]
# 	        Child2 = [0, 7, 1, 8, 3, 2, 4, 5, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 1, 3, 2, 5, 6, 9]
# selection:
# 	        indexes: [7 8 3]
# 	        tournament:
#                  [0, 6, 1, 3, 8, 4, 2, 7, 5, 9]/Len-3927/Fit-2546
#                  [0, 4, 2, 8, 7, 6, 5, 1, 3, 9]/Len-3795/Fit-2635
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# selection:
# 	        indexes: [6 4 8]
# 	        tournament:
#                  [0, 4, 2, 8, 7, 6, 1, 3, 5, 9]/Len-3462/Fit-2888
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 2, 8, 7, 6, 5, 1, 3, 9]/Len-3795/Fit-2635
# 	        winner: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] -> [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# mutation: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] -> [0, 8, 7, 4, 3, 1, 5, 2, 6, 9]
# selection:
# 	        indexes: [0 9 5]
# 	        tournament:
#                  [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
#                  [0, 7, 1, 8, 3, 2, 4, 5, 6, 9]/Len-3741/Fit-2673
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
# 	        winner: [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# selection:
# 	        indexes: [8 4 5]
# 	        tournament:
#                  [0, 4, 2, 8, 7, 6, 5, 1, 3, 9]/Len-3795/Fit-2635
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 1, 8, 5, 2, 4, 7, 3, 6, 9]/Len-4627/Fit-2161
# 	        winner: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# crossover:
# 	        point 5:
# 	        Child1 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] -> [0, 4, 2, 8, 1, 7, 3, 5, 6, 9]
# 	        Child2 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# mutation: [0, 4, 2, 8, 1, 7, 3, 5, 6, 9] -> [0, 4, 8, 2, 1, 7, 3, 5, 6, 9]
#
# ---
#
# Generation 2: Best Fitness = 3526, Best Route = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9], Best Route len = 2836
# Full population:
# [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]/Len-3059/Fit-3269
# [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
# [0, 4, 7, 8, 1, 3, 2, 5, 6, 9]/Len-3608/Fit-2771
# [0, 8, 7, 4, 3, 1, 5, 2, 6, 9]/Len-4451/Fit-2246
# [0, 4, 8, 2, 1, 7, 3, 5, 6, 9]/Len-5087/Fit-1965
# [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#
# selection:
# 	        indexes: [9 2 3]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]/Len-3059/Fit-3269
#                  [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# 	        winner: [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# selection:
# 	        indexes: [7 0 8]
# 	        tournament:
#                  [0, 8, 7, 4, 3, 1, 5, 2, 6, 9]/Len-4451/Fit-2246
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 4, 8, 2, 1, 7, 3, 5, 6, 9]/Len-5087/Fit-1965
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# crossover:
# 	        point 6:
# 	        Child1 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 2, 8, 1, 6, 7, 3, 5, 9]
# 	        Child2 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 5, 2, 6, 1, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# mutation: [0, 4, 2, 8, 1, 6, 7, 3, 5, 9] -> [0, 4, 2, 5, 1, 6, 7, 3, 8, 9]
# selection:
# 	        indexes: [5 7 1]
# 	        tournament:
#                  [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
#                  [0, 8, 7, 4, 3, 1, 5, 2, 6, 9]/Len-4451/Fit-2246
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# selection:
# 	        indexes: [0 9 2]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]/Len-3059/Fit-3269
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# selection:
# 	        indexes: [4 5 2]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
#                  [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]/Len-3059/Fit-3269
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# selection:
# 	        indexes: [8 6 9]
# 	        tournament:
#                  [0, 4, 8, 2, 1, 7, 3, 5, 6, 9]/Len-5087/Fit-1965
#                  [0, 4, 7, 8, 1, 3, 2, 5, 6, 9]/Len-3608/Fit-2771
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 5:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# selection:
# 	        indexes: [3 5 0]
# 	        tournament:
#                  [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
#                  [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# 	        winner: [0, 4, 2, 8, 1, 6, 3, 5, 7, 9]/Len-2836/Fit-3526
# selection:
# 	        indexes: [9 5 4]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 3:
# 	        Child1 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 2, 8, 1, 6, 3, 5, 7, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]
# selection:
# 	        indexes: [6 5 2]
# 	        tournament:
#                  [0, 4, 7, 8, 1, 3, 2, 5, 6, 9]/Len-3608/Fit-2771
#                  [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
#                  [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]/Len-3059/Fit-3269
# 	        winner: [0, 4, 7, 6, 3, 5, 2, 8, 1, 9]/Len-3059/Fit-3269
# selection:
# 	        indexes: [7 9 6]
# 	        tournament:
#                  [0, 8, 7, 4, 3, 1, 5, 2, 6, 9]/Len-4451/Fit-2246
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 7, 8, 1, 3, 2, 5, 6, 9]/Len-3608/Fit-2771
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 5:
# 	        Child1 = [0, 4, 7, 6, 3, 5, 2, 8, 1, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]
# 	        Child2 = [0, 4, 7, 6, 3, 5, 2, 8, 1, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 6, 5, 2, 1, 9]
# mutation: [0, 4, 7, 8, 3, 6, 5, 2, 1, 9] -> [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]
# selection:
# 	        indexes: [1 6 5]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 7, 8, 1, 3, 2, 5, 6, 9]/Len-3608/Fit-2771
#                  [0, 7, 1, 8, 4, 3, 5, 2, 6, 9]/Len-3890/Fit-2570
# 	        winner: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# selection:
# 	        indexes: [9 7 0]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 8, 7, 4, 3, 1, 5, 2, 6, 9]/Len-4451/Fit-2246
#                  [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]/Len-2874/Fit-3479
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 3:
# 	        Child1 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]
# mutation: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]
# mutation: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] -> [0, 4, 7, 8, 6, 1, 5, 2, 3, 9]
#
# ---
#
# Generation 3: Best Fitness = 3895, Best Route = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9], Best Route len = 2567
# Full population:
# [0, 4, 2, 5, 1, 6, 7, 3, 8, 9]/Len-4029/Fit-2482
# [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
# [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]/Len-3836/Fit-2606
# [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]/Len-4977/Fit-2009
# [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#
# selection:
# 	        indexes: [2 5 6]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
# 	        winner: [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# selection:
# 	        indexes: [4 6 3]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 6:
# 	        Child1 = [0, 4, 2, 7, 8, 3, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 2, 7, 8, 3, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# selection:
# 	        indexes: [8 2 1]
# 	        tournament:
#                  [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]/Len-4977/Fit-2009
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# selection:
# 	        indexes: [0 4 3]
# 	        tournament:
#                  [0, 4, 2, 5, 1, 6, 7, 3, 8, 9]/Len-4029/Fit-2482
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 3:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 2, 3, 8, 1, 6, 5, 9]
# selection:
# 	        indexes: [1 6 7]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
#                  [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]/Len-3836/Fit-2606
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# selection:
# 	        indexes: [2 6 8]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
#                  [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]/Len-4977/Fit-2009
# 	        winner: [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
# crossover:
# 	        point 5:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 2, 8, 1, 6, 3, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 2, 8, 1, 6, 3, 5, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 6, 8, 3, 2, 1, 7, 5, 9]
# selection:
# 	        indexes: [9 4 2]
# 	        tournament:
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# selection:
# 	        indexes: [8 3 1]
# 	        tournament:
#                  [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]/Len-4977/Fit-2009
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# selection:
# 	        indexes: [0 2 9]
# 	        tournament:
#                  [0, 4, 2, 5, 1, 6, 7, 3, 8, 9]/Len-4029/Fit-2482
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
# 	        winner: [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# selection:
# 	        indexes: [9 5 6]
# 	        tournament:
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#                  [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
# 	        winner: [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# crossover:
# 	        point 4:
# 	        Child1 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 2, 7, 8, 3, 1, 6, 5, 9] -> [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 1, 5, 2, 6, 9] + [0, 4, 2, 7, 8, 3, 1, 6, 5, 9] -> [0, 4, 2, 7, 8, 3, 1, 5, 6, 9]
# mutation: [0, 4, 2, 7, 8, 3, 1, 5, 6, 9] -> [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]
# selection:
# 	        indexes: [9 3 0]
# 	        tournament:
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 2, 5, 1, 6, 7, 3, 8, 9]/Len-4029/Fit-2482
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# selection:
# 	        indexes: [4 9 2]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
# 	        winner: [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# crossover:
# 	        point 3:
# 	        Child1 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 5, 1, 2, 6, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# selection:
# 	        indexes: [9 7 3]
# 	        tournament:
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#                  [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]/Len-3836/Fit-2606
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# selection:
# 	        indexes: [8 1 7]
# 	        tournament:
#                  [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]/Len-4977/Fit-2009
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]/Len-3836/Fit-2606
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 3:
# 	        Child1 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# selection:
# 	        indexes: [3 8 6]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 8, 7, 3, 6, 5, 2, 1, 9]/Len-4977/Fit-2009
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# selection:
# 	        indexes: [7 2 5]
# 	        tournament:
#                  [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]/Len-3836/Fit-2606
#                  [0, 4, 7, 8, 3, 1, 5, 2, 6, 9]/Len-3245/Fit-3081
#                  [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# 	        winner: [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# crossover:
# 	        point 6:
# 	        Child1 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 2, 7, 8, 3, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 2, 7, 8, 3, 1, 6, 5, 9] -> [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]
# Child already present in population [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# Child already present in population [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]
# selection:
# 	        indexes: [6 1 7]
# 	        tournament:
#                  [0, 4, 7, 2, 8, 1, 6, 3, 5, 9]/Len-3169/Fit-3155
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 7, 6, 3, 8, 2, 1, 5, 9]/Len-3836/Fit-2606
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# selection:
# 	        indexes: [0 9 3]
# 	        tournament:
#                  [0, 4, 2, 5, 1, 6, 7, 3, 8, 9]/Len-4029/Fit-2482
#                  [0, 4, 7, 3, 8, 2, 1, 6, 5, 9]/Len-4315/Fit-2317
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# mutation: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 3, 7, 8, 4, 5, 2, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 5, 1, 6, 2, 9]
#
# ---
#
# Generation 4: Best Fitness = 4450, Best Route = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9], Best Route len = 2247
# Full population:
# [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# [0, 4, 7, 2, 3, 8, 1, 6, 5, 9]/Len-3850/Fit-2597
# [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# [0, 4, 6, 8, 3, 2, 1, 7, 5, 9]/Len-3491/Fit-2864
# [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]/Len-3507/Fit-2851
# [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# [0, 3, 7, 8, 4, 5, 2, 1, 6, 9]/Len-4292/Fit-2329
#
# selection:
# 	        indexes: [8 5 7]
# 	        tournament:
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]/Len-3507/Fit-2851
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# selection:
# 	        indexes: [2 8 9]
# 	        tournament:
#                  [0, 4, 7, 2, 3, 8, 1, 6, 5, 9]/Len-3850/Fit-2597
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 3, 7, 8, 4, 5, 2, 1, 6, 9]/Len-4292/Fit-2329
# 	        winner: [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# crossover:
# 	        point 3:
# 	        Child1 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 5, 2, 7, 8, 3, 1, 4, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 5, 2, 7, 8, 3, 1, 4, 6, 9] -> [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [1 5 0]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# selection:
# 	        indexes: [7 6 3]
# 	        tournament:
#                  [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]/Len-3507/Fit-2851
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 4:
# 	        Child1 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 2, 3, 5, 1, 6, 9]
# mutation: [0, 4, 7, 8, 2, 3, 5, 1, 6, 9] -> [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]
# selection:
# 	        indexes: [7 3 6]
# 	        tournament:
#                  [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]/Len-3507/Fit-2851
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# selection:
# 	        indexes: [3 7 1]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]/Len-3507/Fit-2851
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 1:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]
# selection:
# 	        indexes: [3 1 0]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# selection:
# 	        indexes: [6 8 1]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 1:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 8, 7, 3, 5, 2, 1, 6, 9]
# selection:
# 	        indexes: [7 6 5]
# 	        tournament:
#                  [0, 4, 7, 8, 2, 3, 1, 6, 5, 9]/Len-3507/Fit-2851
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# selection:
# 	        indexes: [5 4 6]
# 	        tournament:
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 6, 8, 3, 2, 1, 7, 5, 9]/Len-3491/Fit-2864
#                  [0, 4, 7, 8, 3, 5, 1, 2, 6, 9]/Len-2982/Fit-3353
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# crossover:
# 	        point 4:
# 	        Child1 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# Child already present in population [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# Child already present in population [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# selection:
# 	        indexes: [2 3 8]
# 	        tournament:
#                  [0, 4, 7, 2, 3, 8, 1, 6, 5, 9]/Len-3850/Fit-2597
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# selection:
# 	        indexes: [0 4 8]
# 	        tournament:
#                  [0, 4, 2, 7, 8, 3, 1, 6, 5, 9]/Len-3133/Fit-3191
#                  [0, 4, 6, 8, 3, 2, 1, 7, 5, 9]/Len-3491/Fit-2864
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# 	        winner: [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# crossover:
# 	        point 7:
# 	        Child1 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 5, 2, 7, 8, 3, 1, 4, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] + [0, 5, 2, 7, 8, 3, 1, 4, 6, 9] -> [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]
# mutation: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]
#
# ---
#
# Generation 5: Best Fitness = 5012, Best Route = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9], Best Route len = 1995
# Full population:
# [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
# [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
# [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
# [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# [0, 4, 8, 7, 3, 5, 2, 1, 6, 9]/Len-4305/Fit-2322
# [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
# [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#
# selection:
# 	        indexes: [0 4 8]
# 	        tournament:
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# selection:
# 	        indexes: [3 4 6]
# 	        tournament:
#                  [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] -> [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]
# selection:
# 	        indexes: [9 7 0]
# 	        tournament:
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 4, 8, 7, 3, 5, 2, 1, 6, 9]/Len-4305/Fit-2322
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# selection:
# 	        indexes: [3 8 2]
# 	        tournament:
#                  [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# crossover:
# 	        point 4:
# 	        Child1 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 2, 5, 8, 3, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [2 0 9]
# 	        tournament:
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# selection:
# 	        indexes: [8 2 9]
# 	        tournament:
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# crossover:
# 	        point 7:
# 	        Child1 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [2 7 9]
# 	        tournament:
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 8, 7, 3, 5, 2, 1, 6, 9]/Len-4305/Fit-2322
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# selection:
# 	        indexes: [4 5 9]
# 	        tournament:
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 8:
# 	        Child1 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# Child already present in population [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# selection:
# 	        indexes: [0 3 1]
# 	        tournament:
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
#                  [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
#                  [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# selection:
# 	        indexes: [5 7 2]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 8, 7, 3, 5, 2, 1, 6, 9]/Len-4305/Fit-2322
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# crossover:
# 	        point 6:
# 	        Child1 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] + [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# Child already present in population [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# selection:
# 	        indexes: [1 2 3]
# 	        tournament:
#                  [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# selection:
# 	        indexes: [9 0 3]
# 	        tournament:
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
#                  [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# crossover:
# 	        point 7:
# 	        Child1 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] -> [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# Child already present in population [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [6 4 1]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
#                  [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
# 	        winner: [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
# selection:
# 	        indexes: [5 7 8]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 8, 7, 3, 5, 2, 1, 6, 9]/Len-4305/Fit-2322
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 5:
# 	        Child1 = [0, 5, 2, 4, 7, 8, 3, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 2, 4, 7, 8, 3, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# Child already present in population [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# selection:
# 	        indexes: [6 1 2]
# 	        tournament:
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# 	        winner: [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
# selection:
# 	        indexes: [4 0 5]
# 	        tournament:
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# crossover:
# 	        point 4:
# 	        Child1 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] -> [0, 4, 7, 2, 5, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 2, 8, 3, 5, 1, 6, 9] + [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# mutation: [0, 4, 7, 2, 5, 8, 3, 1, 6, 9] -> [0, 5, 7, 2, 4, 8, 3, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [4 8 6]
# 	        tournament:
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# 	        winner: [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
# selection:
# 	        indexes: [9 5 8]
# 	        tournament:
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 6:
# 	        Child1 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 2, 5, 1, 6, 9]
# 	        Child2 = [0, 4, 7, 8, 3, 2, 1, 6, 5, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 2, 5, 1, 6, 9] -> [0, 4, 3, 8, 7, 2, 5, 1, 6, 9]
# mutation: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 8, 3, 5, 2, 6, 1, 9]
# selection:
# 	        indexes: [8 1 3]
# 	        tournament:
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
#                  [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
#                  [0, 4, 7, 6, 2, 3, 5, 1, 8, 9]/Len-3717/Fit-2690
# 	        winner: [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
# selection:
# 	        indexes: [9 6 5]
# 	        tournament:
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 4, 7, 8, 3, 2, 1, 6, 5, 9]/Len-2863/Fit-3492
#                  [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# 	        winner: [0, 4, 7, 8, 3, 5, 2, 1, 6, 9]/Len-2567/Fit-3895
# crossover:
# 	        point 3:
# 	        Child1 = [0, 5, 2, 4, 7, 8, 3, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 2, 4, 7, 8, 3, 1, 6, 9] + [0, 4, 7, 8, 3, 5, 2, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# Child already present in population [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [8 9 4]
# 	        tournament:
#                  [0, 4, 3, 8, 7, 5, 2, 1, 6, 9]/Len-3325/Fit-3007
#                  [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
#                  [0, 1, 7, 8, 3, 5, 2, 4, 6, 9]/Len-4444/Fit-2250
# 	        winner: [0, 5, 2, 7, 8, 3, 1, 4, 6, 9]/Len-3098/Fit-3227
# selection:
# 	        indexes: [1 2 0]
# 	        tournament:
#                  [0, 5, 2, 4, 7, 8, 3, 1, 6, 9]/Len-2623/Fit-3812
#                  [0, 4, 7, 2, 8, 3, 5, 1, 6, 9]/Len-2247/Fit-4450
#                  [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# 	        winner: [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]/Len-1995/Fit-5012
# crossover:
# 	        point 5:
# 	        Child1 = [0, 5, 2, 7, 8, 3, 1, 4, 6, 9] + [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] -> [0, 5, 2, 7, 8, 4, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 2, 7, 8, 3, 1, 4, 6, 9] + [0, 4, 7, 5, 2, 8, 3, 1, 6, 9] -> [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
# Child already present in population [0, 4, 7, 5, 2, 8, 3, 1, 6, 9]
#
# ---
#
# ...
#                  [0, 5, 4, 8, 2, 7, 3, 1, 6, 9]/Len-4004/Fit-2497
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# crossover:
# 	        point 8:
# 	        Child1 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# mutation: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 3, 7, 2, 8, 4, 1, 6, 9]
# Child already present in population [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# selection:
# 	        indexes: [5 2 0]
# 	        tournament:
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
#                  [0, 5, 4, 7, 2, 1, 3, 8, 6, 9]/Len-3574/Fit-2797
#                  [0, 5, 8, 4, 7, 2, 1, 3, 6, 9]/Len-3276/Fit-3052
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# selection:
# 	        indexes: [1 7 2]
# 	        tournament:
#                  [0, 5, 4, 2, 1, 7, 8, 3, 6, 9]/Len-3659/Fit-2732
#                  [0, 5, 4, 8, 7, 2, 3, 1, 6, 9]/Len-3248/Fit-3078
#                  [0, 5, 4, 7, 2, 1, 3, 8, 6, 9]/Len-3574/Fit-2797
# 	        winner: [0, 5, 4, 8, 7, 2, 3, 1, 6, 9]/Len-3248/Fit-3078
# crossover:
# 	        point 1:
# 	        Child1 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 5, 4, 8, 7, 2, 3, 1, 6, 9] -> [0, 5, 4, 8, 7, 2, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 5, 4, 8, 7, 2, 3, 1, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# mutation: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 2, 7, 8, 3, 1, 6, 9]
#
# ---
#
# Generation 49: Best Fitness = 5552, Best Route = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9], Best Route len = 1801
# Full population:
# [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
# [0, 5, 4, 7, 2, 6, 3, 8, 1, 9]/Len-3512/Fit-2847
# [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
# [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
# [0, 5, 3, 7, 2, 8, 4, 1, 6, 9]/Len-3312/Fit-3019
# [0, 5, 4, 8, 7, 2, 3, 1, 6, 9]/Len-3248/Fit-3078
#
# selection:
# 	        indexes: [7 2 3]
# 	        tournament:
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
#                  [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
#                  [0, 5, 4, 7, 2, 6, 3, 8, 1, 9]/Len-3512/Fit-2847
# 	        winner: [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
# selection:
# 	        indexes: [6 4 5]
# 	        tournament:
#                  [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# crossover:
# 	        point 2:
# 	        Child1 = [0, 5, 4, 7, 1, 2, 3, 8, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 1, 2, 3, 8, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]
# selection:
# 	        indexes: [0 1 7]
# 	        tournament:
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
#                  [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# selection:
# 	        indexes: [6 3 2]
# 	        tournament:
#                  [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
#                  [0, 5, 4, 7, 2, 6, 3, 8, 1, 9]/Len-3512/Fit-2847
#                  [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
# 	        winner: [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
# crossover:
# 	        point 1:
# 	        Child1 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 3, 8, 4, 7, 5, 6, 1, 2, 9] -> [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]
# 	        Child2 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 3, 8, 4, 7, 5, 6, 1, 2, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# mutation: [0, 3, 8, 4, 7, 5, 6, 1, 2, 9] -> [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]
# mutation: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [6 7 5]
# 	        tournament:
#                  [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# selection:
# 	        indexes: [7 1 6]
# 	        tournament:
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
#                  [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
#                  [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
# 	        winner: [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# crossover:
# 	        point 4:
# 	        Child1 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] -> [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]
# mutation: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]
# Child already present in population [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]
# selection:
# 	        indexes: [7 4 8]
# 	        tournament:
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
#                  [0, 5, 3, 7, 2, 8, 4, 1, 6, 9]/Len-3312/Fit-3019
# 	        winner: [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# selection:
# 	        indexes: [4 0 5]
# 	        tournament:
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# crossover:
# 	        point 3:
# 	        Child1 = [0, 5, 4, 7, 3, 2, 8, 1, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 3, 2, 8, 1, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]
# selection:
# 	        indexes: [7 3 8]
# 	        tournament:
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
#                  [0, 5, 4, 7, 2, 6, 3, 8, 1, 9]/Len-3512/Fit-2847
#                  [0, 5, 3, 7, 2, 8, 4, 1, 6, 9]/Len-3312/Fit-3019
# 	        winner: [0, 5, 3, 7, 2, 8, 4, 1, 6, 9]/Len-3312/Fit-3019
# selection:
# 	        indexes: [3 7 6]
# 	        tournament:
#                  [0, 5, 4, 7, 2, 6, 3, 8, 1, 9]/Len-3512/Fit-2847
#                  [0, 1, 8, 4, 7, 5, 6, 3, 2, 9]/Len-3676/Fit-2720
#                  [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
# 	        winner: [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
# crossover:
# 	        point 8:
# 	        Child1 = [0, 5, 3, 7, 2, 8, 4, 1, 6, 9] + [0, 3, 8, 4, 7, 5, 6, 1, 2, 9] -> [0, 5, 3, 7, 2, 8, 4, 1, 6, 9]
# 	        Child2 = [0, 5, 3, 7, 2, 8, 4, 1, 6, 9] + [0, 3, 8, 4, 7, 5, 6, 1, 2, 9] -> [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]
# mutation: [0, 5, 3, 7, 2, 8, 4, 1, 6, 9] -> [0, 5, 3, 7, 2, 8, 1, 4, 6, 9]
# mutation: [0, 3, 8, 4, 7, 5, 6, 1, 2, 9] -> [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]
# selection:
# 	        indexes: [9 3 5]
# 	        tournament:
#                  [0, 5, 4, 8, 7, 2, 3, 1, 6, 9]/Len-3248/Fit-3078
#                  [0, 5, 4, 7, 2, 6, 3, 8, 1, 9]/Len-3512/Fit-2847
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# selection:
# 	        indexes: [6 5 9]
# 	        tournament:
#                  [0, 3, 8, 4, 7, 5, 6, 1, 2, 9]/Len-3133/Fit-3191
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
#                  [0, 5, 4, 8, 7, 2, 3, 1, 6, 9]/Len-3248/Fit-3078
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# crossover:
# 	        point 3:
# 	        Child1 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# mutation: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]
# Child already present in population [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
#
# ---
#
# Generation 50: Best Fitness = 5552, Best Route = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9], Best Route len = 1801
# Full population:
# [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
# [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]/Len-4264/Fit-2345
# [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]/Len-2658/Fit-3762
# [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# [0, 5, 3, 7, 2, 8, 1, 4, 6, 9]/Len-4142/Fit-2414
# [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]/Len-4214/Fit-2373
# [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]/Len-4655/Fit-2148
#
# selection:
# 	        indexes: [4 2 9]
# 	        tournament:
#                  [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
#                  [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]/Len-4264/Fit-2345
#                  [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]/Len-4655/Fit-2148
# 	        winner: [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# selection:
# 	        indexes: [1 4 3]
# 	        tournament:
#                  [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
#                  [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
#                  [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]/Len-2658/Fit-3762
# 	        winner: [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]/Len-2658/Fit-3762
# crossover:
# 	        point 4:
# 	        Child1 = [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] + [0, 2, 4, 7, 5, 8, 3, 1, 6, 9] -> [0, 1, 4, 7, 2, 5, 8, 3, 6, 9]
# 	        Child2 = [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] + [0, 2, 4, 7, 5, 8, 3, 1, 6, 9] -> [0, 2, 4, 7, 1, 5, 8, 3, 6, 9]
# mutation: [0, 2, 4, 7, 1, 5, 8, 3, 6, 9] -> [0, 6, 4, 7, 1, 5, 8, 3, 2, 9]
# selection:
# 	        indexes: [9 1 0]
# 	        tournament:
#                  [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]/Len-4655/Fit-2148
#                  [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# selection:
# 	        indexes: [9 2 6]
# 	        tournament:
#                  [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]/Len-4655/Fit-2148
#                  [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]/Len-4264/Fit-2345
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# 	        winner: [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# crossover:
# 	        point 4:
# 	        Child1 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 3, 2, 8, 1, 6, 9] -> [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 3, 2, 8, 1, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# mutation: [0, 5, 4, 7, 3, 2, 8, 1, 6, 9] -> [0, 5, 4, 2, 3, 7, 8, 1, 6, 9]
# mutation: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 6, 3, 9]
# selection:
# 	        indexes: [2 3 9]
# 	        tournament:
#                  [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]/Len-4264/Fit-2345
#                  [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]/Len-2658/Fit-3762
#                  [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]/Len-4655/Fit-2148
# 	        winner: [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]/Len-2658/Fit-3762
# selection:
# 	        indexes: [7 5 0]
# 	        tournament:
#                  [0, 5, 3, 7, 2, 8, 1, 4, 6, 9]/Len-4142/Fit-2414
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# crossover:
# 	        point 5:
# 	        Child1 = [0, 2, 4, 7, 5, 8, 3, 1, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 2, 4, 7, 5, 8, 3, 1, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# mutation: [0, 2, 4, 7, 5, 8, 3, 1, 6, 9] -> [0, 2, 5, 7, 4, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [0 8 6]
# 	        tournament:
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
#                  [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]/Len-4214/Fit-2373
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# selection:
# 	        indexes: [2 8 4]
# 	        tournament:
#                  [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]/Len-4264/Fit-2345
#                  [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]/Len-4214/Fit-2373
#                  [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# 	        winner: [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# crossover:
# 	        point 1:
# 	        Child1 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] -> [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# selection:
# 	        indexes: [5 2 8]
# 	        tournament:
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
#                  [0, 3, 8, 4, 1, 5, 6, 7, 2, 9]/Len-4264/Fit-2345
#                  [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]/Len-4214/Fit-2373
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# selection:
# 	        indexes: [8 5 9]
# 	        tournament:
#                  [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]/Len-4214/Fit-2373
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
#                  [0, 5, 4, 8, 1, 2, 7, 3, 6, 9]/Len-4655/Fit-2148
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# crossover:
# 	        point 3:
# 	        Child1 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# Child already present in population [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# Child already present in population [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# selection:
# 	        indexes: [4 1 6]
# 	        tournament:
#                  [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
#                  [0, 5, 4, 7, 1, 2, 3, 8, 6, 9]/Len-3262/Fit-3065
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# 	        winner: [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]/Len-2899/Fit-3449
# selection:
# 	        indexes: [7 0 6]
# 	        tournament:
#                  [0, 5, 3, 7, 2, 8, 1, 4, 6, 9]/Len-4142/Fit-2414
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# crossover:
# 	        point 7:
# 	        Child1 = [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]
# 	        Child2 = [0, 1, 4, 7, 5, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# Child already present in population [0, 1, 4, 7, 5, 2, 8, 3, 6, 9]
# mutation: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 1, 7, 2, 8, 3, 6, 9]
# selection:
# 	        indexes: [3 7 0]
# 	        tournament:
#                  [0, 2, 4, 7, 5, 8, 3, 1, 6, 9]/Len-2658/Fit-3762
#                  [0, 5, 3, 7, 2, 8, 1, 4, 6, 9]/Len-4142/Fit-2414
#                  [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# 	        winner: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]/Len-2400/Fit-4166
# selection:
# 	        indexes: [8 6 5]
# 	        tournament:
#                  [0, 3, 8, 6, 7, 5, 4, 1, 2, 9]/Len-4214/Fit-2373
#                  [0, 5, 4, 7, 3, 2, 8, 1, 6, 9]/Len-3174/Fit-3150
#                  [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# 	        winner: [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]/Len-1801/Fit-5552
# crossover:
# 	        point 4:
# 	        Child1 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# 	        Child2 = [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] + [0, 5, 4, 7, 2, 8, 3, 1, 6, 9] -> [0, 5, 4, 7, 1, 2, 8, 3, 6, 9]
# Child already present in population [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]
# mutation: [0, 5, 4, 7, 1, 2, 8, 3, 6, 9] -> [0, 5, 4, 7, 1, 3, 8, 2, 6, 9]
#
# Best fitness: 5552
# Trace route [0, 5, 4, 7, 2, 8, 3, 1, 6, 9]: 0 -> 72 -> 244 -> 190 -> 565 -> 192 -> 35 -> 161 -> 100 -> 242
# Route len: 1801
